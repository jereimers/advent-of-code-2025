# %% [markdown]
# There are batteries nearby that can supply emergency power to the escalator for just such an occasion. The batteries are each labeled with their joltage rating, a value from 1 to 9. You make a note of their joltage ratings (your puzzle input). For example:
#
# 987654321111111
# 811111111111119
# 234234234234278
# 818181911112111
#
# The batteries are arranged into **banks**; each line of digits in your input corresponds to a single bank of batteries. Within each bank, you need to turn on exactly two batteries; the joltage that the bank produces is equal to the number formed by the digits on the batteries you've turned on. For example, if you have a bank like 12345 and you turn on batteries 2 and 4, the bank would produce 24 jolts. (You cannot rearrange batteries.)
#
# You'll need to find the largest possible joltage each bank can produce. In the above example:
#
# In 987654321111111, you can make the largest joltage possible, 98, by turning on the first two batteries.
# In 811111111111119, you can make the largest joltage possible by turning on the batteries labeled 8 and 9, producing 89 jolts.
# In 234234234234278, you can make 78 by turning on the last two batteries (marked 7 and 8).
# In 818181911112111, the largest joltage you can produce is 92.
# The total output joltage is the sum of the maximum joltage from each bank, so in this example, the total output joltage is 98 + 89 + 78 + 92 = 357.
#
# There are many batteries in front of you. Find the maximum joltage possible from each bank; what is the total output joltage?

# %%
# load input data with file I/O into comma-separated list
with open('03_input.txt', 'r') as f:
    data = f.read().strip()

array = data.split('\n')

print(array)

total_joltage = 0
# Out:
# ['5313313222133223232222173222221322232243522222432422223223232222322322332122525322132232325523243253', '4643434435498557235534365243244542574323553443425455373394347524417545656554254323477646362565332393', '4368355334455444324446443344964445436444444535543564974449455835134465344446457442431444949546837554', '1233222462842264836222323343438133241441433342523522523433233433172523212124472129323343343262452654', '2362522134224321232821151357232125226816156225282228424322226621235652111622222622122733334222262326', '2233213332243221223233334332333533226334323334233232331331333333433321332222323233334913323234443332', '1225233313422232542132242222222233324233322232223233414222321423223214222225334433212352432131235222', '3342347334543433942543737451273434433333343233432323333382732246334543743854334544343335563723323543', '3222132322624622253922334553132235283125122222313123512332223224232223222223224132222242335132223222', '3282814631552455223845495229522528935222522885339443346562862666812722932213358593727594192835645138', '3233316363352423323332643133432127332324513346673332272324223322322342333234215127235142133323223462', '7562776979756656658387595988498688486988985756767968894866858377993945635544787883888848346383698495', '2423342523233632333433246335237343533433233334333444443323353132313343633463333465332326351333333334', '6344263232422272242424224422515334244122441742373344127332642244342423253336652334455642233444244221', '4263222346764242353521553213434222362433623533235353535585333465253355334342446845362314533328455267', '2352965611464332545522224622622269132252542635626322524376442226625438554233234622342433435545433313', '7323327223321312222431322512122333293352222353221313233745233349244221322155228222227632222422232171', '4326155213655552256512115121566354636136336552412561526153523121311531121533431451212556162545643789', '5754355435343324253533474525445715255295353443643538443532445356253335444352435635433353534535334354', '1271122342123362222212332537262221711532123232227721212522222212322732151753735243123225224213212252', '6463363666333363333325623339132554532136343563335757733633631363253322631433333154335335363493339532', '2523333425344543443444643443342325444544444423494444236854344233243432334344432722242473453433534366', '2332332333312227122221115322332223423336224332223211112222323332222212232123112122222221322233233333', '3352123122422232333233232124423212223323231335334223224334431722223211233214322221225332223132221434', '2122222213221221122322222312222222122232121242222212223611122112232322122123222221242212322221122313', '4743535342523226355254245435553345242623344255654364336533333535437534333314533534534253164436442541', '3112443243433125642325443346222222234447122132242422333224222433434142332224433443223222322252422312', '2314223441352322235351313332813662334232336242421232625625125235342524315124328232632322353381752532', '1321312113522222222132428255822223431534222333222322127222222232462423273962121334337252226533329322', '3221624624232121223222123232131234221232221224211222222212223232442132223121442315222221342125252622', '4483394723635394396667347743455135692368657265583357786648362838632545678857725656526543435876486652', '1224184722344322735523331333244222143233234322725232332323232242823123727222222332124228713215634312', '2275392555547777262322627451576277225376642682278371683162746494667733537762746466661465734845254313', '4222332231231222223113322422232143221122223222232232222422222226222332222233221112221212423423335232', '3222222232213221222422234222121222322253221223432112227122223222222323322323121222222211225232222222', '2422122242211222323222221522132322231221422244212322233411322212443351228413222332221512223222222213', '5245543633253455535554552764544455427555664448115455531542265564635526566445465155353554542386664233', '5434346922335634653243472353213634535334323432227224252436227334324223344444623367423532254235384343', '4633342333532432473433333124334233233233323334 ...

# %% [markdown]
# The cell above gets me an array of **banks**.
# My next task: figure out the largest combo of two digits in each bank (element)
#
# # Variables
#
# - `bank_joltage`: the current/apparent joltage from a single bank of batteries
# - `total_joltage`: The total joltage from across all banks
#
# # Constraints
#
# - cannot rearrange order of batteries: `bank_joltage` will always read left-to-right
#
# # Noticings
#
# - Math this reminds me of: combinations and permutations.
#   - Pair bank[0] with each bank[1:]
#   - Then pair bank[1] with each bank[2:]
#   - And so on: bank[i] is the first digit, bank[i+1:] is the set of second digits
#   - Fill a set with these values (losing duplicates is fine; if it's a duplicate, it's probably not the answer)
#   - Then compare to find out which combo is the greatest when cast as `int`
# - How to track their index, however?
#   - easy?! Keep the `best_batteries` variable with you and update it during the above loop.
#   - You don't need to know the indices of the batteries, just their output voltage

# %%
print(list(array[0]))
# Out:
# ['5', '3', '1', '3', '3', '1', '3', '2', '2', '2', '1', '3', '3', '2', '2', '3', '2', '3', '2', '2', '2', '2', '1', '7', '3', '2', '2', '2', '2', '2', '1', '3', '2', '2', '2', '3', '2', '2', '4', '3', '5', '2', '2', '2', '2', '2', '4', '3', '2', '4', '2', '2', '2', '2', '3', '2', '2', '3', '2', '3', '2', '2', '2', '2', '3', '2', '2', '3', '2', '2', '3', '3', '2', '1', '2', '2', '5', '2', '5', '3', '2', '2', '1', '3', '2', '2', '3', '2', '3', '2', '5', '5', '2', '3', '2', '4', '3', '2', '5', '3']

# %% [markdown]
# Now, you need to make the largest joltage by turning on exactly twelve batteries within each bank.
#
# The joltage output for the bank is still the number formed by the digits of the batteries you've turned on; the only difference is that now there will be 12 digits in each bank's joltage output instead of two.
#
# Consider again the example from before:
#
# 987654321111111
# 811111111111119
# 234234234234278
# 818181911112111
# Now, the joltages are much larger:
#
# In 987654321111111, the largest joltage can be found by turning on everything except some 1s at the end to produce 987654321111.
# In the digit sequence 811111111111119, the largest joltage can be found by turning on everything except some 1s, producing 811111111119.
# In 234234234234278, the largest joltage can be found by turning on everything except a 2 battery, a 3 battery, and another 2 battery near the start to produce 434234234278.
# In 818181911112111, the joltage 888911112111 is produced by turning on everything except some 1s near the front.
# The total output joltage is now much larger: 987654321111 + 811111111119 + 434234234278 + 888911112111 = 3121910778619.
#
# What is the new total output joltage?

# %%
# Time to generalize...

def find_largest_joltage(bank, num_digits=12):
    print(f"Finding largest {num_digits}-digit combo in bank of length {len(bank)}: {"".join(bank)}")
    result = []
    start_pos = 0 # where we start searching in the bank

    for i in range(num_digits):
        # How many more digits do we need after this one?
        remaining_needed = num_digits - i + 1
        print(f"Finding digit {i}. Remaining digits needed: {remaining_needed}.")


        if start_pos + remaining_needed > len(bank):
            result.append(bank[start_pos:])
            return

        # Latest index we can pick from
        end_pos = len(bank) - remaining_needed + 1
        try:
            print(f"Digit {i} can be selected from indices {start_pos} ({bank[start_pos]}) to {end_pos} ({bank[end_pos]}).")
        except IndexError:
            break


        # Find the max digit in that valid range
        max_digit = bank[start_pos]
        max_index = start_pos
        print(f"Initializing max_digit = {max_digit} and max_index = {start_pos}")

        for j in range(start_pos, end_pos):
            if bank[j] >= max_digit:
                max_digit = bank[j]
                max_index = j
                print(f"Found digit {i}: {max_digit} at index {max_index}")
        
        # Add to result and move past it
        result.append(max_digit)
        print(f"Current test_joltage: {"".join(result)}")
        start_pos = max_index + 1
        print(f"Resuming search at new start_pos: {start_pos}")

    return int("".join(result))

# test_bank = list(str(5313313222133223232222173222221322232243522222432422223223232222322322332122525322132232325523243253))
# test_joltage = find_largest_joltage(test_bank, 12)
# print(test_joltage)

# %%
test_bank = list(str(5313313222133223232222173222221322232243522222432422223223232222322322332122525322132232325523243253))

# %%
# process each bank
for idx, bank in enumerate(array):
    print(f"Processing Bank #{idx}: {bank}")
    bank_joltage = find_largest_joltage(list(bank), num_digits=12)
    print(f"Bank #{idx} joltage: {bank_joltage}")
    total_joltage += bank_joltage

print(f"Total joltage: {total_joltage }")
# Out:
# Processing Bank #0: 5313313222133223232222173222221322232243522222432422223223232222322322332122525322132232325523243253
# Finding largest 12-digit combo in bank of length 100: 5313313222133223232222173222221322232243522222432422223223232222322322332122525322132232325523243253
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (5) to 90 (5).
# Initializing max_digit = 5 and max_index = 0
# Found digit 0: 5 at index 0
# Found digit 0: 7 at index 23
# Current test_joltage: 7
# Resuming search at new start_pos: 24
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 24 (3) to 91 (5).
# Initializing max_digit = 3 and max_index = 24
# Found digit 1: 3 at index 24
# Found digit 1: 3 at index 31
# Found digit 1: 3 at index 35
# Found digit 1: 4 at index 38
# Found digit 1: 5 at index 40
# Found digit 1: 5 at index 76
# Found digit 1: 5 at index 78
# Found digit 1: 5 at index 90
# Current test_joltage: 75
# Resuming search at new start_pos: 91
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 91 (5) to 92 (2).
# Initializing max_digit = 5 and max_index = 91
# Found digit 2: 5 at index 91
# Current test_joltage: 755
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (2) to 93 (3).
# Initializing max_digit = 2 and max_index = 92
# Found digit 3: 2 at index 92
# Current test_joltage: 7552
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (3) to 94 (2).
# Initializing max_digit = 3 and max_index = 93
# Found digit 4: 3 at index 93
# Current test_joltage: 75523
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (4).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 755232
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (4) to 96 (3).
# Initializing max_digit = 4 and max_index = 95
# Found digit 6: 4 at index 95
# Current test_joltage: 7552324
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (3) to 97 (2).
# Initializing max_digit = 3 and max_index = 96
# Found digit 7: 3 at index 96
# Current test_joltage: 75523243
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (2) to 98 (5).
# Initializing max_digit = 2 and max_index = 97
# Found digit 8: 2 at index 97
# Current test_joltage: 755232432
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (5) to 99 (3).
# Initializing max_digit = 5 and max_index = 98
# Found digit 9: 5 at index 98
# Current test_joltage: 7552324325
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #0 joltage: 7552324325
# Processing Bank #1: 4643434435498557235534365243244542574323553443425455373394347524417545656554254323477646362565332393
# Finding largest 12-digit combo in bank of length 100: 4643434435498557235534365243244542574323553443425455373394347524417545656554254323477646362565332393
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (4) to 90 (2).
# Initializing max_digit = 4 and max_index = 0
# Found digit 0: 4 at index 0
# Found digit 0: 6 at index 1
# Found digit 0: 9 at index 11
# Found digit 0: 9 at index 56
# Current test_joltage: 9
# Resuming search at new start_pos: 57
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 57 (4) to 91 (5).
# Initializing max_digit = 4 and max_index = 57
# Found digit 1: 4 at index 57
# Found digit 1: 4 at index 59
# Found digit 1: 7 at index 60
# Found digit 1: 7 at index 66
# Found digit 1: 7 at index 83
# Found digit 1: 7 at index 84
# Current test_joltage: 97
# Resuming search at new start_pos: 85
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 85 (6) to 92 (6).
# Initializing max_digit = 6 and max_index = 85
# Found digit 2: 6 at index 85
# Found digit 2: 6 at index 87
# Found digit 2: 6 at index 89
# Current test_joltage: 976
# Resuming search at new start_pos: 90
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 90 (2) to 93 (5).
# Initializing max_digit = 2 and max_index = 90
# Found digit 3: 2 at index 90
# Found digit 3: 5 at index 91
# Found digit 3: 6 at index 92
# Current test_joltage: 9766
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (5) to 94 (3).
# Initializing max_digit = 5 and max_index = 93
# Found digit 4: 5 at index 93
# Current test_joltage: 97665
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (3) to 95 (3).
# Initializing max_digit = 3 and max_index = 94
# Found digit 5: 3 at index 94
# Current test_joltage: 976653
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (3) to 96 (2).
# Initializing max_digit = 3 and max_index = 95
# Found digit 6: 3 at index 95
# Current test_joltage: 9766533
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (2) to 97 (3).
# Initializing max_digit = 2 and max_index = 96
# Found digit 7: 2 at index 96
# Current test_joltage: 97665332
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (3) to 98 (9).
# Initializing max_digit = 3 and max_index = 97
# Found digit 8: 3 at index 97
# Current test_joltage: 976653323
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (9) to 99 (3).
# Initializing max_digit = 9 and max_index = 98
# Found digit 9: 9 at index 98
# Current test_joltage: 9766533239
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #1 joltage: 9766533239
# Processing Bank #2: 4368355334455444324446443344964445436444444535543564974449455835134465344446457442431444949546837554
# Finding largest 12-digit combo in bank of length 100: 4368355334455444324446443344964445436444444535543564974449455835134465344446457442431444949546837554
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (4) to 90 (9).
# Initializing max_digit = 4 and max_index = 0
# Found digit 0: 4 at index 0
# Found digit 0: 6 at index 2
# Found digit 0: 8 at index 3
# Found digit 0: 9 at index 28
# Found digit 0: 9 at index 52
# Found digit 0: 9 at index 57
# Found digit 0: 9 at index 88
# Current test_joltage: 9
# Resuming search at new start_pos: 89
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 89 (4) to 91 (5).
# Initializing max_digit = 4 and max_index = 89
# Found digit 1: 4 at index 89
# Found digit 1: 9 at index 90
# Current test_joltage: 99
# Resuming search at new start_pos: 91
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 91 (5) to 92 (4).
# Initializing max_digit = 5 and max_index = 91
# Found digit 2: 5 at index 91
# Current test_joltage: 995
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (4) to 93 (6).
# Initializing max_digit = 4 and max_index = 92
# Found digit 3: 4 at index 92
# Current test_joltage: 9954
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (6) to 94 (8).
# Initializing max_digit = 6 and max_index = 93
# Found digit 4: 6 at index 93
# Current test_joltage: 99546
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (8) to 95 (3).
# Initializing max_digit = 8 and max_index = 94
# Found digit 5: 8 at index 94
# Current test_joltage: 995468
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (3) to 96 (7).
# Initializing max_digit = 3 and max_index = 95
# Found digit 6: 3 at index 95
# Current test_joltage: 9954683
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (7) to 97 (5).
# Initializing max_digit = 7 and max_index = 96
# Found digit 7: 7 at index 96
# Current test_joltage: 99546837
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (5) to 98 (5).
# Initializing max_digit = 5 and max_index = 97
# Found digit 8: 5 at index 97
# Current test_joltage: 995468375
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (5) to 99 (4).
# Initializing max_digit = 5 and max_index = 98
# Found digit 9: 5 at index 98
# Current test_joltage: 9954683755
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #2 joltage: 9954683755
# Processing Bank #3: 1233222462842264836222323343438133241441433342523522523433233433172523212124472129323343343262452654
# Finding largest 12-digit combo in bank of length 100: 1233222462842264836222323343438133241441433342523522523433233433172523212124472129323343343262452654
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (1) to 90 (3).
# Initializing max_digit = 1 and max_index = 0
# Found digit 0: 1 at index 0
# Found digit 0: 2 at index 1
# Found digit 0: 3 at index 2
# Found digit 0: 3 at index 3
# Found digit 0: 4 at index 7
# Found digit 0: 6 at index 8
# Found digit 0: 8 at index 10
# Found digit 0: 8 at index 16
# Found digit 0: 8 at index 30
# Found digit 0: 9 at index 81
# Current test_joltage: 9
# Resuming search at new start_pos: 82
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 82 (3) to 91 (2).
# Initializing max_digit = 3 and max_index = 82
# Found digit 1: 3 at index 82
# Found digit 1: 3 at index 84
# Found digit 1: 3 at index 85
# Found digit 1: 4 at index 86
# Found digit 1: 4 at index 89
# Current test_joltage: 94
# Resuming search at new start_pos: 90
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 90 (3) to 92 (6).
# Initializing max_digit = 3 and max_index = 90
# Found digit 2: 3 at index 90
# Current test_joltage: 943
# Resuming search at new start_pos: 91
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 91 (2) to 93 (2).
# Initializing max_digit = 2 and max_index = 91
# Found digit 3: 2 at index 91
# Found digit 3: 6 at index 92
# Current test_joltage: 9436
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (2) to 94 (4).
# Initializing max_digit = 2 and max_index = 93
# Found digit 4: 2 at index 93
# Current test_joltage: 94362
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (4) to 95 (5).
# Initializing max_digit = 4 and max_index = 94
# Found digit 5: 4 at index 94
# Current test_joltage: 943624
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (5) to 96 (2).
# Initializing max_digit = 5 and max_index = 95
# Found digit 6: 5 at index 95
# Current test_joltage: 9436245
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (2) to 97 (6).
# Initializing max_digit = 2 and max_index = 96
# Found digit 7: 2 at index 96
# Current test_joltage: 94362452
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (6) to 98 (5).
# Initializing max_digit = 6 and max_index = 97
# Found digit 8: 6 at index 97
# Current test_joltage: 943624526
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (5) to 99 (4).
# Initializing max_digit = 5 and max_index = 98
# Found digit 9: 5 at index 98
# Current test_joltage: 9436245265
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #3 joltage: 9436245265
# Processing Bank #4: 2362522134224321232821151357232125226816156225282228424322226621235652111622222622122733334222262326
# Finding largest 12-digit combo in bank of length 100: 2362522134224321232821151357232125226816156225282228424322226621235652111622222622122733334222262326
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (2) to 90 (4).
# Initializing max_digit = 2 and max_index = 0
# Found digit 0: 2 at index 0
# Found digit 0: 3 at index 1
# Found digit 0: 6 at index 2
# Found digit 0: 8 at index 19
# Found digit 0: 8 at index 37
# Found digit 0: 8 at index 47
# Found digit 0: 8 at index 51
# Current test_joltage: 8
# Resuming search at new start_pos: 52
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 52 (4) to 91 (2).
# Initializing max_digit = 4 and max_index = 52
# Found digit 1: 4 at index 52
# Found digit 1: 4 at index 54
# Found digit 1: 6 at index 60
# Found digit 1: 6 at index 61
# Found digit 1: 6 at index 67
# Found digit 1: 6 at index 73
# Found digit 1: 6 at index 79
# Found digit 1: 7 at index 85
# Current test_joltage: 87
# Resuming search at new start_pos: 86
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 86 (3) to 92 (2).
# Initializing max_digit = 3 and max_index = 86
# Found digit 2: 3 at index 86
# Found digit 2: 3 at index 87
# Found digit 2: 3 at index 88
# Found digit 2: 3 at index 89
# Found digit 2: 4 at index 90
# Current test_joltage: 874
# Resuming search at new start_pos: 91
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 91 (2) to 93 (2).
# Initializing max_digit = 2 and max_index = 91
# Found digit 3: 2 at index 91
# Found digit 3: 2 at index 92
# Current test_joltage: 8742
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (2) to 94 (2).
# Initializing max_digit = 2 and max_index = 93
# Found digit 4: 2 at index 93
# Current test_joltage: 87422
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (6).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 874222
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (6) to 96 (2).
# Initializing max_digit = 6 and max_index = 95
# Found digit 6: 6 at index 95
# Current test_joltage: 8742226
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (2) to 97 (3).
# Initializing max_digit = 2 and max_index = 96
# Found digit 7: 2 at index 96
# Current test_joltage: 87422262
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (3) to 98 (2).
# Initializing max_digit = 3 and max_index = 97
# Found digit 8: 3 at index 97
# Current test_joltage: 874222623
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (2) to 99 (6).
# Initializing max_digit = 2 and max_index = 98
# Found digit 9: 2 at index 98
# Current test_joltage: 8742226232
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #4 joltage: 8742226232
# Processing Bank #5: 2233213332243221223233334332333533226334323334233232331331333333433321332222323233334913323234443332
# Finding largest 12-digit combo in bank of length 100: 2233213332243221223233334332333533226334323334233232331331333333433321332222323233334913323234443332
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (2) to 90 (3).
# Initializing max_digit = 2 and max_index = 0
# Found digit 0: 2 at index 0
# Found digit 0: 2 at index 1
# Found digit 0: 3 at index 2
# Found digit 0: 3 at index 3
# Found digit 0: 3 at index 6
# Found digit 0: 3 at index 7
# Found digit 0: 3 at index 8
# Found digit 0: 4 at index 11
# Found digit 0: 4 at index 24
# Found digit 0: 5 at index 31
# Found digit 0: 6 at index 36
# Found digit 0: 9 at index 85
# Current test_joltage: 9
# Resuming search at new start_pos: 86
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 86 (1) to 91 (2).
# Initializing max_digit = 1 and max_index = 86
# Found digit 1: 1 at index 86
# Found digit 1: 3 at index 87
# Found digit 1: 3 at index 88
# Found digit 1: 3 at index 90
# Current test_joltage: 93
# Resuming search at new start_pos: 91
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 91 (2) to 92 (3).
# Initializing max_digit = 2 and max_index = 91
# Found digit 2: 2 at index 91
# Current test_joltage: 932
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (3) to 93 (4).
# Initializing max_digit = 3 and max_index = 92
# Found digit 3: 3 at index 92
# Current test_joltage: 9323
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (4) to 94 (4).
# Initializing max_digit = 4 and max_index = 93
# Found digit 4: 4 at index 93
# Current test_joltage: 93234
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (4) to 95 (4).
# Initializing max_digit = 4 and max_index = 94
# Found digit 5: 4 at index 94
# Current test_joltage: 932344
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (4) to 96 (3).
# Initializing max_digit = 4 and max_index = 95
# Found digit 6: 4 at index 95
# Current test_joltage: 9323444
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (3) to 97 (3).
# Initializing max_digit = 3 and max_index = 96
# Found digit 7: 3 at index 96
# Current test_joltage: 93234443
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (3) to 98 (3).
# Initializing max_digit = 3 and max_index = 97
# Found digit 8: 3 at index 97
# Current test_joltage: 932344433
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (3) to 99 (2).
# Initializing max_digit = 3 and max_index = 98
# Found digit 9: 3 at index 98
# Current test_joltage: 9323444333
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #5 joltage: 9323444333
# Processing Bank #6: 1225233313422232542132242222222233324233322232223233414222321423223214222225334433212352432131235222
# Finding largest 12-digit combo in bank of length 100: 1225233313422232542132242222222233324233322232223233414222321423223214222225334433212352432131235222
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (1) to 90 (2).
# Initializing max_digit = 1 and max_index = 0
# Found digit 0: 1 at index 0
# Found digit 0: 2 at index 1
# Found digit 0: 2 at index 2
# Found digit 0: 5 at index 3
# Found digit 0: 5 at index 16
# Found digit 0: 5 at index 75
# Found digit 0: 5 at index 86
# Current test_joltage: 5
# Resuming search at new start_pos: 87
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 87 (2) to 91 (1).
# Initializing max_digit = 2 and max_index = 87
# Found digit 1: 2 at index 87
# Found digit 1: 4 at index 88
# Current test_joltage: 54
# Resuming search at new start_pos: 89
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 89 (3) to 92 (3).
# Initializing max_digit = 3 and max_index = 89
# Found digit 2: 3 at index 89
# Current test_joltage: 543
# Resuming search at new start_pos: 90
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 90 (2) to 93 (1).
# Initializing max_digit = 2 and max_index = 90
# Found digit 3: 2 at index 90
# Found digit 3: 3 at index 92
# Current test_joltage: 5433
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (1) to 94 (2).
# Initializing max_digit = 1 and max_index = 93
# Found digit 4: 1 at index 93
# Current test_joltage: 54331
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (3).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 543312
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (3) to 96 (5).
# Initializing max_digit = 3 and max_index = 95
# Found digit 6: 3 at index 95
# Current test_joltage: 5433123
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (5) to 97 (2).
# Initializing max_digit = 5 and max_index = 96
# Found digit 7: 5 at index 96
# Current test_joltage: 54331235
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (2) to 98 (2).
# Initializing max_digit = 2 and max_index = 97
# Found digit 8: 2 at index 97
# Current test_joltage: 543312352
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (2) to 99 (2).
# Initializing max_digit = 2 and max_index = 98
# Found digit 9: 2 at index 98
# Current test_joltage: 5433123522
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #6 joltage: 5433123522
# Processing Bank #7: 3342347334543433942543737451273434433333343233432323333382732246334543743854334544343335563723323543
# Finding largest 12-digit combo in bank of length 100: 3342347334543433942543737451273434433333343233432323333382732246334543743854334544343335563723323543
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (3) to 90 (3).
# Initializing max_digit = 3 and max_index = 0
# Found digit 0: 3 at index 0
# Found digit 0: 3 at index 1
# Found digit 0: 4 at index 2
# Found digit 0: 4 at index 5
# Found digit 0: 7 at index 6
# Found digit 0: 9 at index 16
# Current test_joltage: 9
# Resuming search at new start_pos: 17
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 17 (4) to 91 (7).
# Initializing max_digit = 4 and max_index = 17
# Found digit 1: 4 at index 17
# Found digit 1: 5 at index 19
# Found digit 1: 7 at index 22
# Found digit 1: 7 at index 24
# Found digit 1: 7 at index 29
# Found digit 1: 8 at index 56
# Found digit 1: 8 at index 73
# Current test_joltage: 98
# Resuming search at new start_pos: 74
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 74 (5) to 92 (2).
# Initializing max_digit = 5 and max_index = 74
# Found digit 2: 5 at index 74
# Found digit 2: 5 at index 79
# Found digit 2: 5 at index 87
# Found digit 2: 5 at index 88
# Found digit 2: 6 at index 89
# Found digit 2: 7 at index 91
# Current test_joltage: 987
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (2) to 93 (3).
# Initializing max_digit = 2 and max_index = 92
# Found digit 3: 2 at index 92
# Current test_joltage: 9872
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (3) to 94 (3).
# Initializing max_digit = 3 and max_index = 93
# Found digit 4: 3 at index 93
# Current test_joltage: 98723
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (3) to 95 (2).
# Initializing max_digit = 3 and max_index = 94
# Found digit 5: 3 at index 94
# Current test_joltage: 987233
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (2) to 96 (3).
# Initializing max_digit = 2 and max_index = 95
# Found digit 6: 2 at index 95
# Current test_joltage: 9872332
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (3) to 97 (5).
# Initializing max_digit = 3 and max_index = 96
# Found digit 7: 3 at index 96
# Current test_joltage: 98723323
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (5) to 98 (4).
# Initializing max_digit = 5 and max_index = 97
# Found digit 8: 5 at index 97
# Current test_joltage: 987233235
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (4) to 99 (3).
# Initializing max_digit = 4 and max_index = 98
# Found digit 9: 4 at index 98
# Current test_joltage: 9872332354
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #7 joltage: 9872332354
# Processing Bank #8: 3222132322624622253922334553132235283125122222313123512332223224232223222223224132222242335132223222
# Finding largest 12-digit combo in bank of length 100: 3222132322624622253922334553132235283125122222313123512332223224232223222223224132222242335132223222
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (3) to 90 (5).
# Initializing max_digit = 3 and max_index = 0
# Found digit 0: 3 at index 0
# Found digit 0: 3 at index 5
# Found digit 0: 3 at index 7
# Found digit 0: 6 at index 10
# Found digit 0: 6 at index 13
# Found digit 0: 9 at index 19
# Current test_joltage: 9
# Resuming search at new start_pos: 20
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 20 (2) to 91 (1).
# Initializing max_digit = 2 and max_index = 20
# Found digit 1: 2 at index 20
# Found digit 1: 2 at index 21
# Found digit 1: 3 at index 22
# Found digit 1: 3 at index 23
# Found digit 1: 4 at index 24
# Found digit 1: 5 at index 25
# Found digit 1: 5 at index 26
# Found digit 1: 5 at index 33
# Found digit 1: 8 at index 35
# Current test_joltage: 98
# Resuming search at new start_pos: 36
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 36 (3) to 92 (3).
# Initializing max_digit = 3 and max_index = 36
# Found digit 2: 3 at index 36
# Found digit 2: 5 at index 39
# Found digit 2: 5 at index 52
# Found digit 2: 5 at index 90
# Current test_joltage: 985
# Resuming search at new start_pos: 91
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 91 (1) to 93 (2).
# Initializing max_digit = 1 and max_index = 91
# Found digit 3: 1 at index 91
# Found digit 3: 3 at index 92
# Current test_joltage: 9853
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (2) to 94 (2).
# Initializing max_digit = 2 and max_index = 93
# Found digit 4: 2 at index 93
# Current test_joltage: 98532
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (2).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 985322
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (2) to 96 (3).
# Initializing max_digit = 2 and max_index = 95
# Found digit 6: 2 at index 95
# Current test_joltage: 9853222
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (3) to 97 (2).
# Initializing max_digit = 3 and max_index = 96
# Found digit 7: 3 at index 96
# Current test_joltage: 98532223
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (2) to 98 (2).
# Initializing max_digit = 2 and max_index = 97
# Found digit 8: 2 at index 97
# Current test_joltage: 985322232
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (2) to 99 (2).
# Initializing max_digit = 2 and max_index = 98
# Found digit 9: 2 at index 98
# Current test_joltage: 9853222322
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #8 joltage: 9853222322
# Processing Bank #9: 3282814631552455223845495229522528935222522885339443346562862666812722932213358593727594192835645138
# Finding largest 12-digit combo in bank of length 100: 3282814631552455223845495229522528935222522885339443346562862666812722932213358593727594192835645138
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (3) to 90 (2).
# Initializing max_digit = 3 and max_index = 0
# Found digit 0: 3 at index 0
# Found digit 0: 8 at index 2
# Found digit 0: 8 at index 4
# Found digit 0: 8 at index 19
# Found digit 0: 9 at index 23
# Found digit 0: 9 at index 27
# Found digit 0: 9 at index 34
# Found digit 0: 9 at index 48
# Found digit 0: 9 at index 70
# Found digit 0: 9 at index 80
# Found digit 0: 9 at index 86
# Found digit 0: 9 at index 89
# Current test_joltage: 9
# Resuming search at new start_pos: 90
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 90 (2) to 91 (8).
# Initializing max_digit = 2 and max_index = 90
# Found digit 1: 2 at index 90
# Current test_joltage: 92
# Resuming search at new start_pos: 91
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 91 (8) to 92 (3).
# Initializing max_digit = 8 and max_index = 91
# Found digit 2: 8 at index 91
# Current test_joltage: 928
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (3) to 93 (5).
# Initializing max_digit = 3 and max_index = 92
# Found digit 3: 3 at index 92
# Current test_joltage: 9283
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (5) to 94 (6).
# Initializing max_digit = 5 and max_index = 93
# Found digit 4: 5 at index 93
# Current test_joltage: 92835
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (6) to 95 (4).
# Initializing max_digit = 6 and max_index = 94
# Found digit 5: 6 at index 94
# Current test_joltage: 928356
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (4) to 96 (5).
# Initializing max_digit = 4 and max_index = 95
# Found digit 6: 4 at index 95
# Current test_joltage: 9283564
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (5) to 97 (1).
# Initializing max_digit = 5 and max_index = 96
# Found digit 7: 5 at index 96
# Current test_joltage: 92835645
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (1) to 98 (3).
# Initializing max_digit = 1 and max_index = 97
# Found digit 8: 1 at index 97
# Current test_joltage: 928356451
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (3) to 99 (8).
# Initializing max_digit = 3 and max_index = 98
# Found digit 9: 3 at index 98
# Current test_joltage: 9283564513
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #9 joltage: 9283564513
# Processing Bank #10: 3233316363352423323332643133432127332324513346673332272324223322322342333234215127235142133323223462
# Finding largest 12-digit combo in bank of length 100: 3233316363352423323332643133432127332324513346673332272324223322322342333234215127235142133323223462
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (3) to 90 (3).
# Initializing max_digit = 3 and max_index = 0
# Found digit 0: 3 at index 0
# Found digit 0: 3 at index 2
# Found digit 0: 3 at index 3
# Found digit 0: 3 at index 4
# Found digit 0: 6 at index 6
# Found digit 0: 6 at index 8
# Found digit 0: 6 at index 22
# Found digit 0: 7 at index 33
# Found digit 0: 7 at index 47
# Found digit 0: 7 at index 53
# Found digit 0: 7 at index 81
# Current test_joltage: 7
# Resuming search at new start_pos: 82
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 82 (2) to 91 (3).
# Initializing max_digit = 2 and max_index = 82
# Found digit 1: 2 at index 82
# Found digit 1: 3 at index 83
# Found digit 1: 5 at index 84
# Current test_joltage: 75
# Resuming search at new start_pos: 85
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 85 (1) to 92 (2).
# Initializing max_digit = 1 and max_index = 85
# Found digit 2: 1 at index 85
# Found digit 2: 4 at index 86
# Current test_joltage: 754
# Resuming search at new start_pos: 87
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 87 (2) to 93 (3).
# Initializing max_digit = 2 and max_index = 87
# Found digit 3: 2 at index 87
# Found digit 3: 3 at index 89
# Found digit 3: 3 at index 90
# Found digit 3: 3 at index 91
# Current test_joltage: 7543
# Resuming search at new start_pos: 92
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 92 (2) to 94 (2).
# Initializing max_digit = 2 and max_index = 92
# Found digit 4: 2 at index 92
# Found digit 4: 3 at index 93
# Current test_joltage: 75433
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (2).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 754332
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (2) to 96 (3).
# Initializing max_digit = 2 and max_index = 95
# Found digit 6: 2 at index 95
# Current test_joltage: 7543322
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (3) to 97 (4).
# Initializing max_digit = 3 and max_index = 96
# Found digit 7: 3 at index 96
# Current test_joltage: 75433223
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (4) to 98 (6).
# Initializing max_digit = 4 and max_index = 97
# Found digit 8: 4 at index 97
# Current test_joltage: 754332234
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (6) to 99 (2).
# Initializing max_digit = 6 and max_index = 98
# Found digit 9: 6 at index 98
# Current test_joltage: 7543322346
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #10 joltage: 7543322346
# Processing Bank #11: 7562776979756656658387595988498688486988985756767968894866858377993945635544787883888848346383698495
# Finding largest 12-digit combo in bank of length 100: 7562776979756656658387595988498688486988985756767968894866858377993945635544787883888848346383698495
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (7) to 90 (6).
# Initializing max_digit = 7 and max_index = 0
# Found digit 0: 7 at index 0
# Found digit 0: 7 at index 4
# Found digit 0: 7 at index 5
# Found digit 0: 9 at index 7
# Found digit 0: 9 at index 9
# Found digit 0: 9 at index 23
# Found digit 0: 9 at index 25
# Found digit 0: 9 at index 29
# Found digit 0: 9 at index 37
# Found digit 0: 9 at index 40
# Found digit 0: 9 at index 49
# Found digit 0: 9 at index 53
# Found digit 0: 9 at index 64
# Found digit 0: 9 at index 65
# Found digit 0: 9 at index 67
# Current test_joltage: 9
# Resuming search at new start_pos: 68
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 68 (4) to 91 (3).
# Initializing max_digit = 4 and max_index = 68
# Found digit 1: 4 at index 68
# Found digit 1: 5 at index 69
# Found digit 1: 6 at index 70
# Found digit 1: 7 at index 76
# Found digit 1: 8 at index 77
# Found digit 1: 8 at index 79
# Found digit 1: 8 at index 80
# Found digit 1: 8 at index 82
# Found digit 1: 8 at index 83
# Found digit 1: 8 at index 84
# Found digit 1: 8 at index 85
# Found digit 1: 8 at index 87
# Current test_joltage: 98
# Resuming search at new start_pos: 88
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 88 (3) to 92 (8).
# Initializing max_digit = 3 and max_index = 88
# Found digit 2: 3 at index 88
# Found digit 2: 4 at index 89
# Found digit 2: 6 at index 90
# Current test_joltage: 986
# Resuming search at new start_pos: 91
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 91 (3) to 93 (3).
# Initializing max_digit = 3 and max_index = 91
# Found digit 3: 3 at index 91
# Found digit 3: 8 at index 92
# Current test_joltage: 9868
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (3) to 94 (6).
# Initializing max_digit = 3 and max_index = 93
# Found digit 4: 3 at index 93
# Current test_joltage: 98683
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (6) to 95 (9).
# Initializing max_digit = 6 and max_index = 94
# Found digit 5: 6 at index 94
# Current test_joltage: 986836
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (9) to 96 (8).
# Initializing max_digit = 9 and max_index = 95
# Found digit 6: 9 at index 95
# Current test_joltage: 9868369
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (8) to 97 (4).
# Initializing max_digit = 8 and max_index = 96
# Found digit 7: 8 at index 96
# Current test_joltage: 98683698
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (4) to 98 (9).
# Initializing max_digit = 4 and max_index = 97
# Found digit 8: 4 at index 97
# Current test_joltage: 986836984
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (9) to 99 (5).
# Initializing max_digit = 9 and max_index = 98
# Found digit 9: 9 at index 98
# Current test_joltage: 9868369849
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #11 joltage: 9868369849
# Processing Bank #12: 2423342523233632333433246335237343533433233334333444443323353132313343633463333465332326351333333334
# Finding largest 12-digit combo in bank of length 100: 2423342523233632333433246335237343533433233334333444443323353132313343633463333465332326351333333334
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (2) to 90 (1).
# Initializing max_digit = 2 and max_index = 0
# Found digit 0: 2 at index 0
# Found digit 0: 4 at index 1
# Found digit 0: 4 at index 5
# Found digit 0: 5 at index 7
# Found digit 0: 6 at index 13
# Found digit 0: 6 at index 24
# Found digit 0: 7 at index 30
# Current test_joltage: 7
# Resuming search at new start_pos: 31
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 31 (3) to 91 (3).
# Initializing max_digit = 3 and max_index = 31
# Found digit 1: 3 at index 31
# Found digit 1: 4 at index 32
# Found digit 1: 5 at index 34
# Found digit 1: 5 at index 59
# Found digit 1: 6 at index 70
# Found digit 1: 6 at index 74
# Found digit 1: 6 at index 80
# Found digit 1: 6 at index 87
# Current test_joltage: 76
# Resuming search at new start_pos: 88
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 88 (3) to 92 (3).
# Initializing max_digit = 3 and max_index = 88
# Found digit 2: 3 at index 88
# Found digit 2: 5 at index 89
# Current test_joltage: 765
# Resuming search at new start_pos: 90
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 90 (1) to 93 (3).
# Initializing max_digit = 1 and max_index = 90
# Found digit 3: 1 at index 90
# Found digit 3: 3 at index 91
# Found digit 3: 3 at index 92
# Current test_joltage: 7653
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (3) to 94 (3).
# Initializing max_digit = 3 and max_index = 93
# Found digit 4: 3 at index 93
# Current test_joltage: 76533
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (3) to 95 (3).
# Initializing max_digit = 3 and max_index = 94
# Found digit 5: 3 at index 94
# Current test_joltage: 765333
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (3) to 96 (3).
# Initializing max_digit = 3 and max_index = 95
# Found digit 6: 3 at index 95
# Current test_joltage: 7653333
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (3) to 97 (3).
# Initializing max_digit = 3 and max_index = 96
# Found digit 7: 3 at index 96
# Current test_joltage: 76533333
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (3) to 98 (3).
# Initializing max_digit = 3 and max_index = 97
# Found digit 8: 3 at index 97
# Current test_joltage: 765333333
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (3) to 99 (4).
# Initializing max_digit = 3 and max_index = 98
# Found digit 9: 3 at index 98
# Current test_joltage: 7653333333
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #12 joltage: 7653333333
# Processing Bank #13: 6344263232422272242424224422515334244122441742373344127332642244342423253336652334455642233444244221
# Finding largest 12-digit combo in bank of length 100: 6344263232422272242424224422515334244122441742373344127332642244342423253336652334455642233444244221
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (6) to 90 (3).
# Initializing max_digit = 6 and max_index = 0
# Found digit 0: 6 at index 0
# Found digit 0: 6 at index 5
# Found digit 0: 7 at index 14
# Found digit 0: 7 at index 43
# Found digit 0: 7 at index 47
# Found digit 0: 7 at index 54
# Current test_joltage: 7
# Resuming search at new start_pos: 55
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 55 (3) to 91 (4).
# Initializing max_digit = 3 and max_index = 55
# Found digit 1: 3 at index 55
# Found digit 1: 3 at index 56
# Found digit 1: 6 at index 58
# Found digit 1: 6 at index 75
# Found digit 1: 6 at index 76
# Found digit 1: 6 at index 85
# Current test_joltage: 76
# Resuming search at new start_pos: 86
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 86 (4) to 92 (4).
# Initializing max_digit = 4 and max_index = 86
# Found digit 2: 4 at index 86
# Found digit 2: 4 at index 91
# Current test_joltage: 764
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (4) to 93 (4).
# Initializing max_digit = 4 and max_index = 92
# Found digit 3: 4 at index 92
# Current test_joltage: 7644
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (4) to 94 (2).
# Initializing max_digit = 4 and max_index = 93
# Found digit 4: 4 at index 93
# Current test_joltage: 76444
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (4).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 764442
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (4) to 96 (4).
# Initializing max_digit = 4 and max_index = 95
# Found digit 6: 4 at index 95
# Current test_joltage: 7644424
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (4) to 97 (2).
# Initializing max_digit = 4 and max_index = 96
# Found digit 7: 4 at index 96
# Current test_joltage: 76444244
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (2) to 98 (2).
# Initializing max_digit = 2 and max_index = 97
# Found digit 8: 2 at index 97
# Current test_joltage: 764442442
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (2) to 99 (1).
# Initializing max_digit = 2 and max_index = 98
# Found digit 9: 2 at index 98
# Current test_joltage: 7644424422
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #13 joltage: 7644424422
# Processing Bank #14: 4263222346764242353521553213434222362433623533235353535585333465253355334342446845362314533328455267
# Finding largest 12-digit combo in bank of length 100: 4263222346764242353521553213434222362433623533235353535585333465253355334342446845362314533328455267
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (4) to 90 (3).
# Initializing max_digit = 4 and max_index = 0
# Found digit 0: 4 at index 0
# Found digit 0: 6 at index 2
# Found digit 0: 6 at index 9
# Found digit 0: 7 at index 10
# Found digit 0: 8 at index 56
# Found digit 0: 8 at index 79
# Current test_joltage: 8
# Resuming search at new start_pos: 80
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 80 (4) to 91 (3).
# Initializing max_digit = 4 and max_index = 80
# Found digit 1: 4 at index 80
# Found digit 1: 5 at index 81
# Found digit 1: 6 at index 83
# Current test_joltage: 86
# Resuming search at new start_pos: 84
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 84 (2) to 92 (2).
# Initializing max_digit = 2 and max_index = 84
# Found digit 2: 2 at index 84
# Found digit 2: 3 at index 85
# Found digit 2: 4 at index 87
# Found digit 2: 5 at index 88
# Current test_joltage: 865
# Resuming search at new start_pos: 89
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 89 (3) to 93 (8).
# Initializing max_digit = 3 and max_index = 89
# Found digit 3: 3 at index 89
# Found digit 3: 3 at index 90
# Found digit 3: 3 at index 91
# Current test_joltage: 8653
# Resuming search at new start_pos: 92
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 92 (2) to 94 (4).
# Initializing max_digit = 2 and max_index = 92
# Found digit 4: 2 at index 92
# Found digit 4: 8 at index 93
# Current test_joltage: 86538
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (4) to 95 (5).
# Initializing max_digit = 4 and max_index = 94
# Found digit 5: 4 at index 94
# Current test_joltage: 865384
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (5) to 96 (5).
# Initializing max_digit = 5 and max_index = 95
# Found digit 6: 5 at index 95
# Current test_joltage: 8653845
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (5) to 97 (2).
# Initializing max_digit = 5 and max_index = 96
# Found digit 7: 5 at index 96
# Current test_joltage: 86538455
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (2) to 98 (6).
# Initializing max_digit = 2 and max_index = 97
# Found digit 8: 2 at index 97
# Current test_joltage: 865384552
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (6) to 99 (7).
# Initializing max_digit = 6 and max_index = 98
# Found digit 9: 6 at index 98
# Current test_joltage: 8653845526
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #14 joltage: 8653845526
# Processing Bank #15: 2352965611464332545522224622622269132252542635626322524376442226625438554233234622342433435545433313
# Finding largest 12-digit combo in bank of length 100: 2352965611464332545522224622622269132252542635626322524376442226625438554233234622342433435545433313
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (2) to 90 (5).
# Initializing max_digit = 2 and max_index = 0
# Found digit 0: 2 at index 0
# Found digit 0: 3 at index 1
# Found digit 0: 5 at index 2
# Found digit 0: 9 at index 4
# Found digit 0: 9 at index 33
# Current test_joltage: 9
# Resuming search at new start_pos: 34
# ...
# Digit 0 can be selected from indices 0 (2) to 90 (2).
# Initializing max_digit = 2 and max_index = 0
# Found digit 0: 2 at index 0
# Found digit 0: 3 at index 1
# Found digit 0: 3 at index 2
# Found digit 0: 3 at index 4
# Found digit 0: 5 at index 5
# Found digit 0: 5 at index 13
# Found digit 0: 5 at index 15
# Current test_joltage: 5
# Resuming search at new start_pos: 16
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 16 (2) to 91 (2).
# Initializing max_digit = 2 and max_index = 16
# Found digit 1: 2 at index 16
# Found digit 1: 2 at index 17
# Found digit 1: 3 at index 18
# Found digit 1: 3 at index 19
# Found digit 1: 3 at index 32
# Found digit 1: 3 at index 34
# Found digit 1: 3 at index 39
# Found digit 1: 3 at index 40
# Found digit 1: 4 at index 42
# Found digit 1: 4 at index 49
# Found digit 1: 4 at index 67
# Found digit 1: 4 at index 72
# Found digit 1: 4 at index 73
# Found digit 1: 4 at index 74
# Found digit 1: 4 at index 84
# Current test_joltage: 54
# Resuming search at new start_pos: 85
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 85 (2) to 92 (4).
# Initializing max_digit = 2 and max_index = 85
# Found digit 2: 2 at index 85
# Found digit 2: 2 at index 86
# Found digit 2: 3 at index 87
# Current test_joltage: 543
# Resuming search at new start_pos: 88
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 88 (2) to 93 (2).
# Initializing max_digit = 2 and max_index = 88
# Found digit 3: 2 at index 88
# Found digit 3: 2 at index 89
# Found digit 3: 2 at index 90
# Found digit 3: 2 at index 91
# Found digit 3: 4 at index 92
# Current test_joltage: 5434
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (2) to 94 (2).
# Initializing max_digit = 2 and max_index = 93
# Found digit 4: 2 at index 93
# Current test_joltage: 54342
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (1).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 543422
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (1) to 96 (2).
# Initializing max_digit = 1 and max_index = 95
# Found digit 6: 1 at index 95
# Current test_joltage: 5434221
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (2) to 97 (2).
# Initializing max_digit = 2 and max_index = 96
# Found digit 7: 2 at index 96
# Current test_joltage: 54342212
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (2) to 98 (1).
# Initializing max_digit = 2 and max_index = 97
# Found digit 8: 2 at index 97
# Current test_joltage: 543422122
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (1) to 99 (2).
# Initializing max_digit = 1 and max_index = 98
# Found digit 9: 1 at index 98
# Current test_joltage: 5434221221
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #195 joltage: 5434221221
# Processing Bank #196: 8347746465549236644542999639825787796367996837855363266895862457593656589493494366731898836266662777
# Finding largest 12-digit combo in bank of length 100: 8347746465549236644542999639825787796367996837855363266895862457593656589493494366731898836266662777
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (8) to 90 (6).
# Initializing max_digit = 8 and max_index = 0
# Found digit 0: 8 at index 0
# Found digit 0: 9 at index 12
# Found digit 0: 9 at index 22
# Found digit 0: 9 at index 23
# Found digit 0: 9 at index 24
# Found digit 0: 9 at index 27
# Found digit 0: 9 at index 35
# Found digit 0: 9 at index 40
# Found digit 0: 9 at index 41
# Found digit 0: 9 at index 56
# Found digit 0: 9 at index 65
# Found digit 0: 9 at index 72
# Found digit 0: 9 at index 74
# Found digit 0: 9 at index 77
# Found digit 0: 9 at index 86
# Current test_joltage: 9
# Resuming search at new start_pos: 87
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 87 (8) to 91 (2).
# Initializing max_digit = 8 and max_index = 87
# Found digit 1: 8 at index 87
# Found digit 1: 8 at index 88
# Current test_joltage: 98
# Resuming search at new start_pos: 89
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 89 (3) to 92 (6).
# Initializing max_digit = 3 and max_index = 89
# Found digit 2: 3 at index 89
# Found digit 2: 6 at index 90
# Current test_joltage: 986
# Resuming search at new start_pos: 91
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 91 (2) to 93 (6).
# Initializing max_digit = 2 and max_index = 91
# Found digit 3: 2 at index 91
# Found digit 3: 6 at index 92
# Current test_joltage: 9866
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (6) to 94 (6).
# Initializing max_digit = 6 and max_index = 93
# Found digit 4: 6 at index 93
# Current test_joltage: 98666
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (6) to 95 (6).
# Initializing max_digit = 6 and max_index = 94
# Found digit 5: 6 at index 94
# Current test_joltage: 986666
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (6) to 96 (2).
# Initializing max_digit = 6 and max_index = 95
# Found digit 6: 6 at index 95
# Current test_joltage: 9866666
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (2) to 97 (7).
# Initializing max_digit = 2 and max_index = 96
# Found digit 7: 2 at index 96
# Current test_joltage: 98666662
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (7) to 98 (7).
# Initializing max_digit = 7 and max_index = 97
# Found digit 8: 7 at index 97
# Current test_joltage: 986666627
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (7) to 99 (7).
# Initializing max_digit = 7 and max_index = 98
# Found digit 9: 7 at index 98
# Current test_joltage: 9866666277
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #196 joltage: 9866666277
# Processing Bank #197: 4424354676333339442474444434444431444464349769463134635934583654444544325845361424874634496848144343
# Finding largest 12-digit combo in bank of length 100: 4424354676333339442474444434444431444464349769463134635934583654444544325845361424874634496848144343
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (4) to 90 (6).
# Initializing max_digit = 4 and max_index = 0
# Found digit 0: 4 at index 0
# Found digit 0: 4 at index 1
# Found digit 0: 4 at index 3
# Found digit 0: 5 at index 5
# Found digit 0: 6 at index 7
# Found digit 0: 7 at index 8
# Found digit 0: 9 at index 15
# Found digit 0: 9 at index 42
# Found digit 0: 9 at index 45
# Found digit 0: 9 at index 55
# Found digit 0: 9 at index 89
# Current test_joltage: 9
# Resuming search at new start_pos: 90
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 90 (6) to 91 (8).
# Initializing max_digit = 6 and max_index = 90
# Found digit 1: 6 at index 90
# Current test_joltage: 96
# Resuming search at new start_pos: 91
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 91 (8) to 92 (4).
# Initializing max_digit = 8 and max_index = 91
# Found digit 2: 8 at index 91
# Current test_joltage: 968
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (4) to 93 (8).
# Initializing max_digit = 4 and max_index = 92
# Found digit 3: 4 at index 92
# Current test_joltage: 9684
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (8) to 94 (1).
# Initializing max_digit = 8 and max_index = 93
# Found digit 4: 8 at index 93
# Current test_joltage: 96848
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (1) to 95 (4).
# Initializing max_digit = 1 and max_index = 94
# Found digit 5: 1 at index 94
# Current test_joltage: 968481
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (4) to 96 (4).
# Initializing max_digit = 4 and max_index = 95
# Found digit 6: 4 at index 95
# Current test_joltage: 9684814
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (4) to 97 (3).
# Initializing max_digit = 4 and max_index = 96
# Found digit 7: 4 at index 96
# Current test_joltage: 96848144
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (3) to 98 (4).
# Initializing max_digit = 3 and max_index = 97
# Found digit 8: 3 at index 97
# Current test_joltage: 968481443
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (4) to 99 (3).
# Initializing max_digit = 4 and max_index = 98
# Found digit 9: 4 at index 98
# Current test_joltage: 9684814434
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #197 joltage: 9684814434
# Processing Bank #198: 2212334322343334333444423132132353333334343332232343333332323434233533333335432322312333223332223434
# Finding largest 12-digit combo in bank of length 100: 2212334322343334333444423132132353333334343332232343333332323434233533333335432322312333223332223434
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (2) to 90 (3).
# Initializing max_digit = 2 and max_index = 0
# Found digit 0: 2 at index 0
# Found digit 0: 2 at index 1
# Found digit 0: 2 at index 3
# Found digit 0: 3 at index 4
# Found digit 0: 3 at index 5
# Found digit 0: 4 at index 6
# Found digit 0: 4 at index 11
# Found digit 0: 4 at index 15
# Found digit 0: 4 at index 19
# Found digit 0: 4 at index 20
# Found digit 0: 4 at index 21
# Found digit 0: 4 at index 22
# Found digit 0: 5 at index 32
# Found digit 0: 5 at index 67
# Found digit 0: 5 at index 75
# Current test_joltage: 5
# Resuming search at new start_pos: 76
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 76 (4) to 91 (3).
# Initializing max_digit = 4 and max_index = 76
# Found digit 1: 4 at index 76
# Current test_joltage: 54
# Resuming search at new start_pos: 77
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 77 (3) to 92 (3).
# Initializing max_digit = 3 and max_index = 77
# Found digit 2: 3 at index 77
# Found digit 2: 3 at index 79
# Found digit 2: 3 at index 82
# Found digit 2: 3 at index 85
# Found digit 2: 3 at index 86
# Found digit 2: 3 at index 87
# Found digit 2: 3 at index 90
# Found digit 2: 3 at index 91
# Current test_joltage: 543
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (3) to 93 (2).
# Initializing max_digit = 3 and max_index = 92
# Found digit 3: 3 at index 92
# Current test_joltage: 5433
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (2) to 94 (2).
# Initializing max_digit = 2 and max_index = 93
# Found digit 4: 2 at index 93
# Current test_joltage: 54332
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (2).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 543322
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (2) to 96 (3).
# Initializing max_digit = 2 and max_index = 95
# Found digit 6: 2 at index 95
# Current test_joltage: 5433222
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (3) to 97 (4).
# Initializing max_digit = 3 and max_index = 96
# Found digit 7: 3 at index 96
# Current test_joltage: 54332223
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (4) to 98 (3).
# Initializing max_digit = 4 and max_index = 97
# Found digit 8: 4 at index 97
# Current test_joltage: 543322234
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (3) to 99 (4).
# Initializing max_digit = 3 and max_index = 98
# Found digit 9: 3 at index 98
# Current test_joltage: 5433222343
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #198 joltage: 5433222343
# Processing Bank #199: 4536334834426354666653548333733764333733325524343558454435334323934332564372337559263534255825234943
# Finding largest 12-digit combo in bank of length 100: 4536334834426354666653548333733764333733325524343558454435334323934332564372337559263534255825234943
# Finding digit 0. Remaining digits needed: 11.
# Digit 0 can be selected from indices 0 (4) to 90 (5).
# Initializing max_digit = 4 and max_index = 0
# Found digit 0: 4 at index 0
# Found digit 0: 5 at index 1
# Found digit 0: 6 at index 3
# Found digit 0: 8 at index 7
# Found digit 0: 8 at index 24
# Found digit 0: 8 at index 51
# Found digit 0: 9 at index 64
# Found digit 0: 9 at index 81
# Current test_joltage: 9
# Resuming search at new start_pos: 82
# Finding digit 1. Remaining digits needed: 10.
# Digit 1 can be selected from indices 82 (2) to 91 (8).
# Initializing max_digit = 2 and max_index = 82
# Found digit 1: 2 at index 82
# Found digit 1: 6 at index 83
# Current test_joltage: 96
# Resuming search at new start_pos: 84
# Finding digit 2. Remaining digits needed: 9.
# Digit 2 can be selected from indices 84 (3) to 92 (2).
# Initializing max_digit = 3 and max_index = 84
# Found digit 2: 3 at index 84
# Found digit 2: 5 at index 85
# Found digit 2: 5 at index 89
# Found digit 2: 5 at index 90
# Found digit 2: 8 at index 91
# Current test_joltage: 968
# Resuming search at new start_pos: 92
# Finding digit 3. Remaining digits needed: 8.
# Digit 3 can be selected from indices 92 (2) to 93 (5).
# Initializing max_digit = 2 and max_index = 92
# Found digit 3: 2 at index 92
# Current test_joltage: 9682
# Resuming search at new start_pos: 93
# Finding digit 4. Remaining digits needed: 7.
# Digit 4 can be selected from indices 93 (5) to 94 (2).
# Initializing max_digit = 5 and max_index = 93
# Found digit 4: 5 at index 93
# Current test_joltage: 96825
# Resuming search at new start_pos: 94
# Finding digit 5. Remaining digits needed: 6.
# Digit 5 can be selected from indices 94 (2) to 95 (3).
# Initializing max_digit = 2 and max_index = 94
# Found digit 5: 2 at index 94
# Current test_joltage: 968252
# Resuming search at new start_pos: 95
# Finding digit 6. Remaining digits needed: 5.
# Digit 6 can be selected from indices 95 (3) to 96 (4).
# Initializing max_digit = 3 and max_index = 95
# Found digit 6: 3 at index 95
# Current test_joltage: 9682523
# Resuming search at new start_pos: 96
# Finding digit 7. Remaining digits needed: 4.
# Digit 7 can be selected from indices 96 (4) to 97 (9).
# Initializing max_digit = 4 and max_index = 96
# Found digit 7: 4 at index 96
# Current test_joltage: 96825234
# Resuming search at new start_pos: 97
# Finding digit 8. Remaining digits needed: 3.
# Digit 8 can be selected from indices 97 (9) to 98 (4).
# Initializing max_digit = 9 and max_index = 97
# Found digit 8: 9 at index 97
# Current test_joltage: 968252349
# Resuming search at new start_pos: 98
# Finding digit 9. Remaining digits needed: 2.
# Digit 9 can be selected from indices 98 (4) to 99 (3).
# Initializing max_digit = 4 and max_index = 98
# Found digit 9: 4 at index 98
# Current test_joltage: 9682523494
# Resuming search at new start_pos: 99
# Finding digit 10. Remaining digits needed: 1.
# Bank #199 joltage: 9682523494
# Total joltage: 1706271628049
